# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
import sklearn.preprocessing
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import sem
from sklearn import preprocessing, linear_model, svm
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import KFold
from sklearn import metrics
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARMA
from statsmodels.stats.stattools import durbin_watson
from scipy.stats import norm, pareto, kstest
from statsmodels.graphics.gofplots import qqplot
import pandas.tseries

# %%
dataset = pd.read_csv('../data/all_data.csv')

# %%
# convert encoding
le = sklearn.preprocessing.LabelEncoder()
dataset['res_max_type'] = le.fit_transform(dataset['res_max_type'])

# %%
def splitToTrainTest(dataframe, trainPercent):
    recordNum = dataframe.shape[0]
    shuffledIndex = np.random.permutation(np.arange(recordNum))
    trainSetNum = int(recordNum * trainPercent)
    trainDf, testDf = dataframe.iloc[shuffledIndex[:trainSetNum]], dataframe.iloc[shuffledIndex[trainSetNum:]]
    return trainDf, testDf
train_df, test_df = splitToTrainTest(dataset, 0.7)

# %%
# ['count', 'type', 'avg_house_rent_price', 'avg_house_sell_price', 'lat', 'lon']
y_labels = ['LEVEL_MISDEMEANOR']#['Y']
irrelevant_labels = ['lat', 'lon', 'date', 'time', 'zipcode', 'LEVEL_FELONY', 'LEVEL_MISDEMEANOR', 'LEVEL_VIOLATION'] + y_labels

# %%
clf = DecisionTreeClassifier(criterion='entropy')
X_train, X_test = train_df.drop(irrelevant_labels, axis='columns'), test_df.drop(irrelevant_labels, axis='columns') 
y_train, y_test = train_df[y_labels], test_df[y_labels]
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
new_df = pd.DataFrame({'importance':clf.feature_importances_, 'feature':X_train.columns.values})
new_df.sort_values('importance', axis = 0, inplace = True)
fig, ax = plt.subplots()
ax.bar(np.arange(len(new_df['importance'].values)), new_df['importance'].values, width = 0.2, color='b')
ax.set_xticks(np.arange(len(new_df['importance'].values)))
ax.set_xticklabels(new_df['feature'].values, rotation=-90)
plt.title('Feature Importance using Decision Tree model')
ax.set_ylabel('Normalized Gini Importance')
# Out:
# Text(0,0.5,'Normalized Gini Importance')

# %%
train_df[[col_name for col_name in train_df.columns if col_name not in irrelevant_labels] + y_labels].corr()
# Out:
#                              res_max_type  res_max_type_count  \
# res_max_type                     1.000000            0.509871
# res_max_type_count               0.509871            1.000000
# res_total_count                  0.526663            0.942933
# avg_house_sell_price             0.295487            0.303901
# avg_house_rent_price             0.397882            0.580083
# lib_count1                      -0.013789           -0.030676
# lib_count5                      -0.134442           -0.224380
# lib_count15                     -0.227652           -0.376054
# mus_count1                       0.218723            0.393914
# mus_count5                       0.258708            0.403506
# mus_count15                      0.277938            0.389459
# store_business_type_count        0.350123            0.580085
# store_individual_type_count      0.100920           -0.030168
# univ_count1                      0.263417            0.320354
# univ_count5                      0.288320            0.338093
# univ_count15                     0.243875            0.304510
# population                       0.113717            0.027110
# hospital_count5                  0.024594           -0.062046
# hospital_count10                -0.012314           -0.111108
# hospital_count15                -0.017168           -0.137475
# park_area                       -0.036019           -0.059172
# LEVEL_MISDEMEANOR                0.014737            0.008395
#
#                              res_total_count  avg_house_sell_price  \
# res_max_type                        0.526663              0.295487
# res_max_type_count                  0.942933              0.303901
# res_total_count                     1.000000              0.366627
# avg_house_sell_price                0.366627              1.000000
# avg_house_rent_price                0.573834              0.283371
# lib_count1                         -0.021711             -0.128700
# lib_count5                         -0.161859             -0.185648
# lib_count15                        -0.305429             -0.261121
# mus_count1                          0.415270              0.401301
# mus_count5                          0.434993              0.490785
# mus_count15                         0.400720              0.425915
# store_business_type_count           0.675580              0.014892
# store_individual_type_count         0.027158             -0.226253
# univ_count1                         0.325739              0.207305
# univ_count5                         0.348799              0.333812
# univ_count15                        0.321069              0.321304
# population                          0.124739             -0.224143
# hospital_count5                     0.001595             -0.033930
# hospital_count10                   -0.059114             -0.038272
# hospital_count15                   -0.084851             -0.041967
# park_area                          -0.012954             -0.172842
# LEVEL_MISDEMEANOR                   0.013296              0.012266
#
#                              avg_house_rent_price  lib_count1  lib_count5  \
# res_max_type                             0.397882   -0.013789   -0.134442
# res_max_type_count                       0.580083   -0.030676   -0.224380
# res_total_count                          0.573834   -0.021711   -0.161859
# avg_house_sell_price                     0.283371   -0.128700   -0.185648
# avg_house_rent_price                     1.000000   -0.201892   -0.338293
# lib_count1                              -0.201892    1.000000    0.594368
# lib_count5                              -0.338293    0.594368    1.000000
# lib_count15                             -0.459926    0.369963    0.783389
# mus_count1                               0.495175    0.026062   -0.230276
# mus_count5                               0.539841   -0.083582   -0.236719
# mus_count15                              0.617378   -0.129251   -0.234792
# store_business_type_count                0.077397    0.186313    0.185806
# store_individual_type_count             -0.348961    0.268908    0.335784
# univ_count1                              0.466483   -0.049139   -0.088476
# univ_count5                              0.544986   -0.105284   -0.061817
# univ_count15                             0.608672   -0.148681   -0.146845
# population                              -0.233671    0.360966    0.509047
# hospital_count5                          0.034467    0.059119    0.286876
# hospital_count10                         0.024870    0.018915    0.284489
# hospital_count15                         0.044695   -0.013761    0.248353
# park_area                               -0.168501    0.203393    0.216482
# LEVEL_MISDEMEANOR                        0.014052   -0.010526   -0.006063
#
#                              lib_count15  mus_count1  mus_count5  \
# res_max_type                   -0.227652    0.218723    0.258708
# res_max_type_count             -0.376054    0.393914    0.403506
# res_total_count                -0.305429    0.415270    0.434993
# avg_house_sell_price           -0.261121    0.401301    0.490785
# avg_house_rent_price           -0.459926    0.495175    0.539841
# lib_count1                      0.369963    0.026062   -0.083582
# lib_count5                      0.783389   -0.230276   -0.236719
# lib_count15                     1.000000   -0.308686   -0.305353
# mus_count1                     -0.308686    1.000000    0.830968
# mus_count5                     -0.305353    0.830968    1.000000
# mus_count15                    -0.245899    0.684906    0.904533
# store_business_type_count       0.148577    0.089182   -0.000117
# store_individual_type_count     0.366203   -0.231138   -0.311885
# univ_count1                    -0.161175    0.388187    0.426538
# univ_count5                    -0.127496    0.422929    0.583416
# univ_count15                   -0.114214    0.474830    0.633525
# population                      0.516415   -0.197265   -0.265326
# hospital_count5                 0.238247   -0.116102   -0.120353
# hospital_count10                0.295762   -0.119247   -0.105770
# hospital_count15                0.298841   -0.113420   -0.089344
# park_area                       0.158787   -0.130808   -0.182110
# LEVEL_MISDEMEANOR               0.003769    0.012133    0.019815
#
#                                    ...          store_individual_type_count  \
# res_max_type                       ...                             0.100920
# res_max_type_count                 ...                            -0.030168
# res_total_count                    ...                             0.027158
# avg_house_sell_price               ...                            -0.226253
# avg_house_rent_price               ...                            -0.348961
# lib_count1                         ...                             0.268908
# lib_count5                         ...                             0.335784
# lib_count15                        ...                             0.366203
# mus_count1                         ...                            -0.231138
# mus_count5                         ...                            -0.311885
# mus_count15                        ...                            -0.329767
# store_business_type_count          ...                             0.593085
# store_individual_type_count        ...                             1.000000
# univ_count1                        ...                            -0.252138
# univ_count5                        ...                            -0.313309
# univ_count15                       ...                            -0.372357
# population                         ...                             0.586031
# hospital_count5                    ...                            -0.070230
# hospital_count10                   ...                            -0.078770
# hospital_count15                   ...                            -0.092694
# park_area                          ...                             0.258584
# LEVEL_MISDEMEANOR                  ...                             0.000539
#
#                              univ_count1  univ_count5  univ_count15  \
# res_max_type                    0.263417     0.288320      0.243875
# res_max_type_count              0.320354     0.338093      0.304510
# res_total_count                 0.325739     0.348799      0.321069
# avg_house_sell_price            0.207305     0.333812      0.321304
# avg_house_rent_price            0.466483     0.544986      0.608672
# lib_count1                     -0.049139    -0.105284     -0.148681
# lib_count5                     -0.088476    -0.061817     -0.146845
# lib_count15                    -0.161175    -0.127496     -0.114214
# mus_count1                      0.388187     0.422929      0.474830
# mus_count5                      0.426538     0.583416      0.633525
# mus_count15                     0.430251     0.638872      0.762333
# store_business_type_count      -0.003186    -0.051640     -0.117981
# store_individual_type_count    -0.252138    -0.313309     -0.372357
# univ_count1                     1.000000     0.766549      0.595434
# univ_count5                     0.766549     1.000000      0.857669
# univ_count15                    0.595434     0.857669      1.000000
# population                     -0.150910    -0.154311     -0.199774
# hospital_count5                 0.107655     0.153852      0.254902
# hospital_count10                0.074401     0.148657      0.305126
# hospital_count15                0.061490     0.154910      0.331540
# park_area                      -0.153376    -0.169510     -0.135700
# LEVEL_MISDEMEANOR               0.008687     0.017968      0.029692
#
#                              population  hospital_count5  hospital_count10  \
# res_max_type                   0.113717         0.024594         -0.012314
# res_max_type_count             0.027110        -0.062046         -0.111108
# res_total_count                0.124739         0.001595         -0.059114
# avg_house_sell_price          -0.224143        -0.033930         -0.038272
# avg_house_rent_price          -0.233671         0.034467          0.024870
# lib_count1                     0.360966         0.059119          0.018915
# lib_count5                     0.509047         0.286876          0.284489
# lib_count15                    0.516415         0.238247          0.295762
# mus_count1                    -0.197265        -0.116102         -0.119247
# mus_count5                    -0.265326        -0.120353         -0.105770
# mus_count15                   -0.256605        -0.052366         -0.025301
# store_business_type_count      0.590613         0.008641         -0.054048
# store_individual_type_count    0.586031        -0.070230         -0.078770
# univ_count1                   -0.150910         0.107655          0.074401
# univ_count5                   -0.154311         0.153852          0.148657
# univ_count15                  -0.199774         0.254902          0.305126
# population                     1.000000         0.207081          0.152157
# hospital_count5                0.207081         1.000000          0.949447
# hospital_count10               0.152157         0.949447          1.000000
# hospital_count15               0.123560         0.909300          0.985650
# park_area                      0.386795         0.225824          0.197683
# LEVEL_MISDEMEANOR             -0.001614         0.000304          0.003517
#
#                              hospital_count15  park_area  LEVEL_MISDEMEANOR
# res_max_type                        -0.017168  -0.036019           0.014737
# res_max_type_count                  -0.137475  -0.059172           0.008395
# res_total_count                     -0.084851  -0.012954           0.013296
# avg_house_sell_price                -0.041967  -0.172842           0.012266
# avg_house_rent_price                 0.044695  -0.168501           0.014052
# lib_count1                          -0.013761   0.203393          -0.010526
# lib_count5                           0.248353   0.216482          -0.006063
# lib_count15                          0.298841   0.158787           0.003769
# mus_count1                          -0.113420  -0.130808           0.012133
# mus_count5                          -0.089344  -0.182110           0.019815
# mus_count15                          0.004818  -0.189974           0.029896
# store_business_type_count           -0.088500   0.243147           0.006876
# store_individual_type_count         -0.092694   0.258584           0.000539
# univ_count1                          0.061490  -0.153376           0.008687
# univ_count5                          0.154910  -0.169510           0.017968
# univ_count15                         0.331540  -0.135700           0.029692
# population                           0.123560   0.386795          -0.001614
# hospital_count5                      0.909300   0.225824           0.000304
# hospital_count10                     0.985650   0.197683           0.003517
# hospital_count15                     1.000000   0.191893           0.005359
# park_area                            0.191893   1.000000           0.000681
# LEVEL_MISDEMEANOR                    0.005359   0.000681           1.000000
#
# [22 rows x 22 columns]

# %%
train_predict = clf.predict(X_train)
test_predict = clf.predict(X_test)
train_accuracy = metrics.accuracy_score(train_predict, y_train)
test_accuracy = metrics.accuracy_score(test_predict, y_test)

print('Train accuracy = {}\nTest accuracy = {}'.format(train_accuracy, test_accuracy))
# Out:
# Train accuracy = 0.5587619827464992
# Test accuracy = 0.5555426895167516

# %%
# svm
def plotROC(classifiers, classifier_names, X_train, y_train, X_test, y_test):
    plt.figure()
    for classifier, classifier_name in zip(classifiers, classifier_names):
        # Learn to predict
        y_score = classifier.fit(X_train, y_train).decision_function(X_test)

        # Compute ROC curve and ROC area
        fpr, tpr, threshold = roc_curve(y_test, y_score)
        roc_auc = auc(fpr, tpr)
    
        # Plot
        lw = 2
        rand_color = np.random.rand(3,)
        plt.plot(fpr, tpr, c=rand_color,
                 lw=lw, label='%s ROC curve (area = %0.2f)' % (classifier_name, roc_auc))

    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %%
# build model

# logistic regression model
logistic_regression_model = linear_model.LogisticRegression(C = 1e30)

sampled_train = train_df.sample(40000)
sampled_X_train = sampled_train.drop(irrelevant_labels, axis='columns')
sampled_y_train = sampled_train[y_labels]
data_train = {'X': preprocessing.scale(sampled_X_train), 'y': np.asarray(sampled_y_train.values.ravel(), dtype=np.int)}
data_test = {'X':preprocessing.scale(X_test), 'y':np.asarray(y_test.values.ravel(), dtype=np.int)}

# svm model
svm_model = svm.SVC(kernel = 'linear')


# plot roc curve for logistic regression model and svm model
plotROC([logistic_regression_model, svm_model], ['Logistic Regression', 'SVM'],\
        data_train['X'], data_train['y'], data_test['X'], data_test['y'])

# %%
new_dataset = dataset.copy()
new_dataset['Y'] = new_dataset['LEVEL_FELONY']+new_dataset['LEVEL_MISDEMEANOR']*2+new_dataset['LEVEL_VIOLATION']*4

# %%
new_dataset.groupby('Y').size()
# Out:
# Y
# 1    104370
# 2    190937
# 4     50131
# dtype: int64

# %%
raw_crime_data = pd.read_csv('../new_data/NYPD_Complaint_Data_Current_YTD.csv')
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0        160932883   09/30/2017     23:46:00          NaN          NaN
# 1        491504201   09/30/2017     23:20:00   09/30/2017     23:35:00
# 2        670710700   09/30/2017     23:20:00   09/30/2017     23:25:00
# 3        316507505   09/30/2017     23:20:00          NaN          NaN
# 4        942412568   09/30/2017     23:15:00   09/30/2017     23:15:00
# 5        207887383   09/30/2017     23:10:00   09/30/2017     23:12:00
# 6        914858070   09/30/2017     23:10:00   09/30/2017     23:18:00
# 7        646012974   09/30/2017     23:09:00          NaN          NaN
# 8        690078111   09/30/2017     23:05:00   09/30/2017     23:22:00
# 9        269331366   09/30/2017     23:02:00   09/30/2017     23:05:00
# 10       453426697   09/30/2017     23:00:00   09/30/2017     23:05:00
# 11       215350992   09/30/2017     23:00:00   09/30/2017     23:05:00
# 12       768475572   09/30/2017     23:00:00   09/30/2017     23:05:00
# 13       700133466   09/30/2017     23:00:00   09/30/2017     23:05:00
# 14       820145294   09/30/2017     23:00:00   09/30/2017     23:05:00
# 15       259710762   09/30/2017     22:55:00   09/30/2017     23:00:00
# 16       426538114   09/30/2017     22:45:00   09/30/2017     23:00:00
# 17       945791069   09/30/2017     22:40:00   09/30/2017     22:45:00
# 18       175087726   09/30/2017     22:40:00   09/30/2017     22:45:00
# 19       328273384   09/30/2017     22:40:00   09/30/2017     23:03:00
# 20       931452774   09/30/2017     22:40:00   09/30/2017     22:45:00
# 21       129139910   09/30/2017     22:30:00   09/30/2017     22:43:00
# 22       289939419   09/30/2017     22:30:00   09/30/2017     22:35:00
# 23       799920257   09/30/2017     22:30:00   09/30/2017     22:35:00
# 24       184137467   09/30/2017     22:30:00   09/30/2017     22:45:00
# 25       541167749   09/30/2017     22:30:00   09/30/2017     22:55:00
# 26       721819050   09/30/2017     22:30:00   09/30/2017     22:45:00
# 27       329028931   09/30/2017     22:22:00   09/30/2017     22:30:00
# 28       311449610   09/30/2017     22:20:00   09/30/2017     22:30:00
# 29       656711379   09/30/2017     22:15:00   09/30/2017     22:21:00
# ...            ...          ...          ...          ...          ...
# 351479   257531441   12/16/2016     15:25:00   12/16/2016     15:30:00
# 351480   924787396   12/15/2016     22:01:00   12/15/2016     22:03:00
# 351481   626569375   12/10/2016     19:00:00   12/11/2016     12:00:00
# 351482   514844467   12/10/2016     14:00:00   12/10/2016     15:00:00
# 351483   376183862   12/09/2016     01:00:00   12/14/2016     22:00:00
# 351484   419208730   12/05/2016     23:00:00   12/05/2016     23:10:00
# 351485   564382220   12/04/2016     20:00:00   12/06/2016     08:00:00
# 351486   421318231   12/03/2016     16:00:00   01/01/2017     10:00:00
# 351487   736943522   12/03/2016     15:00:00   12/20/2016     15:00:00
# 351488   264440192   12/03/2016     03:30:00   12/03/2016     03:40:00
# 351489   832707021   12/01/2016     16:00:00   01/08/2017     11:50:00
# 351490   781849083   11/30/2016     21:00:00   11/30/2016     21:15:00
# 351491   564963325   11/16/2016     00:30:00   11/16/2016     01:00:00
# 351492   120230345   10/27/2016     00:01:00   10/27/2016     23:00:00
# 351493   227833735   10/21/2016     13:00:00   10/21/2016     13:15:00
# 351494   548130183   10/13/2016     01:30:00   10/13/2016     02:00:00
# 351495   693530867   10/12/2016     10:00:00          NaN          NaN
# 351496   637293210   10/05/2016     00:00:00   01/01/2017     21:16:00
# 351497   766452024   10/04/2016     09:00:00   10/04/2016     09:30:00
# 351498   486460516   07/01/2016     00:01:00   01/01/2017     16:40:00
# 351499   977298651   05/29/2016     12:29:00          NaN          NaN
# 351500   243551498   04/01/2016     00:00:00   06/01/2016     23:59:00
# 351501   181622017   03/01/2016     13:00:00   01/01/2017     22:30:00
# 351502   626739714   01/01/2016     06:10:00   01/01/2017     06:12:00
# 351503   492890715   01/01/2016     06:00:00   01/01/2017     06:15:00
# 351504   657605513   01/01/2016     04:00:00   01/01/2016     04:10:00
# 351505   553117159   01/01/2016     03:00:00   01/01/2017     07:00:00
# 351506   473961688   12/01/2015     00:00:00   12/01/2015     00:00:00
# 351507   479719874   07/01/2015     18:05:00   07/01/2015     18:15:00
# 351508   329336049   10/01/2012     00:01:00   10/01/2012     00:01:00
#
#             RPT_DT  KY_CD                        OFNS_DESC  PD_CD  \
# 0       09/30/2017    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 1       09/30/2017    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 2       09/30/2017    347   INTOXICATED & IMPAIRED DRIVING  905.0
# 3       09/30/2017    578                    HARRASSMENT 2  638.0
# 4       09/30/2017    105                          ROBBERY  384.0
# 5       09/30/2017    235                  DANGEROUS DRUGS  567.0
# 6       09/30/2017    105                          ROBBERY  390.0
# 7       09/30/2017    235                  DANGEROUS DRUGS  511.0
# 8       09/30/2017    106                   FELONY ASSAULT  109.0
# 9       09/30/2017    341                    PETIT LARCENY  333.0
# 10      09/30/2017    348         VEHICLE AND TRAFFIC LAWS  916.0
# 11      09/30/2017    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 12      09/30/2017    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 13      09/30/2017    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 14      09/30/2017    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 15      09/30/2017    348         VEHICLE AND TRAFFIC LAWS  922.0
# 16      09/30/2017    344     ASSAULT 3 & RELATED OFFENSES  114.0
# 17      09/30/2017    351   CRIMINAL MISCHIEF & RELATED OF  258.0
# 18      09/30/2017    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 19      09/30/2017    341                    PETIT LARCENY  321.0
# 20      09/30/2017    344     ASSAULT 3 & RELATED OFFENSES  114.0
# 21      09/30/2017    348         VEHICLE AND TRAFFIC LAWS  922.0
# 22      09/30/2017    109                    GRAND LARCENY  404.0
# 23      09/30/2017    117                  DANGEROUS DRUGS  568.0
# 24      09/30/2017    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 25      09/30/2017    105                          ROBBERY  397.0
# 26      09/30/2017    578                    HARRASSMENT 2  638.0
# 27      09/30/2017    235                  DANGEROUS DRUGS  567.0
# 28      09/30/2017    578                    HARRASSMENT 2  637.0
# 29      09/30/2017    118                DANGEROUS WEAPONS  792.0
# ...            ...    ...                              ...    ...
# 351479  01/01/2017    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 351480  01/01/2017    341                    PETIT LARCENY  339.0
# 351481  01/01/2017    351   CRIMINAL MISCHIEF & RELATED OF  254.0
# 351482  01/01/2017    112                      THEFT-FRAUD  739.0
# 351483  01/01/2017    351   CRIMINAL MISCHIEF & RELATED OF  258.0
# 351484  01/01/2017    106                   FELONY ASSAULT  109.0
# 351485  01/01/2017    351   CRIMINAL MISCHIEF & RELATED OF  258.0
# 351486  01/01/2017    341                    PETIT LARCENY  321.0
# 351487  01/01/2017    109                    GRAND LARCENY  422.0
# 351488  01/01/2017    578                    HARRASSMENT 2  638.0
# 351489  01/01/2017    341                    PETIT LARCENY  339.0
# 351490  01/01/2017    678          MISCELLANEOUS PENAL LAW  201.0
# 351491  01/01/2017    351   CRIMINAL MISCHIEF & RELATED OF  259.0
# 351492  01/01/2017    341                    PETIT LARCENY  339.0
# 351493  01/01/2017    578                    HARRASSMENT 2  637.0
# 351494  01/01/2017    106                   FELONY ASSAULT  109.0
# 351495  01/01/2017    341                    PETIT LARCENY  338.0
# 351496  01/01/2017    112                      THEFT-FRAUD  739.0
# 351497  01/01/2017    109                    GRAND LARCENY  432.0
# 351498  01/01/2017    361    OFF. AGNST PUB ORD SENSBLTY &  639.0
# 351499  01/01/2017    361    OFF. AGNST PUB ORD SENSBLTY &  639.0
# 351500  01/01/2017    116                       SEX CRIMES  177.0
# 351501  01/01/2017    578                    HARRASSMENT 2  638.0
# 351502  01/01/2017    348         VEHICLE AND TRAFFIC LAWS  916.0
# 351503  01/01/2017    341                    PETIT LARCENY  313.0
# 351504  01/01/2017    351   CRIMINAL MISCHIEF & RELATED OF  259.0
# 351505  01/01/2017    341                    PETIT LARCENY  338.0
# 351506  01/01/2017    112                      THEFT-FRAUD  739.0
# 351507  01/01/2017    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 351508  01/01/2017    104                             RAPE  153.0
#
#                                                   PD_DESC  \
# 0                                                     NaN
# 1                                               ASSAULT 3
# 2                             INTOXICATED DRIVING,ALCOHOL
# 3                                   HARASSMENT,SUBD 3,4,5
# 4                          ROBBERY,POCKETBOOK/CARRIED BAG
# 5                             MARIJUANA, POSSESSION 4 & 5
# 6                                   ROBBERY,HOME INVASION
# 7                          CONTROLLED SUBSTANCE, POSSESSI
# 8                                ASSAULT 2,1,UNCLASSIFIED
# 9                          LARCENY,PETIT FROM STORE-SHOPL
# 10                         LEAVING SCENE-ACCIDENT-PERSONA
# 11                                              ASSAULT 3
# 12                                              ASSAULT 3
# 13                                              ASSAULT 3
# 14                                              ASSAULT 3
# 15                         TRAFFIC,UNCLASSIFIED MISDEMEAN
# 16                                    OBSTR BREATH/CIRCUL
# 17                         CRIMINAL MISCHIEF 4TH, GRAFFIT
# 18                                              ASSAULT 3
# 19                                LARCENY,PETIT FROM AUTO
# 20                                    OBSTR BREATH/CIRCUL
# 21                         TRAFFIC,UNCLASSIFIED MISDEMEAN
# 22      LARCENY,GRAND FROM PERSON,PERSONAL ELECTRONIC ...
# 23                         MARIJUANA, POSSESSION 1, 2 & 3
# 24                                              ASSAULT 3
# 25                         ROBBERY,OPEN AREA UNCLASSIFIED
# 26                                  HARASSMENT,SUBD 3,4,5
# 27                            MARIJUANA, POSSESSION 4 & 5
# 28                             HARASSMENT,SUBD 1,CIVILIAN
# 29                               WEAPONS POSSESSION 1 & 2
# ...                                                   ...
# 351479                                          ASSAULT 3
# 351480                     LARCENY,PETIT FROM OPEN AREAS,
# 351481                     MISCHIEF, CRIMINAL 4, OF MOTOR
# 351482                          FRAUD,UNCLASSIFIED-FELONY
# 351483                     CRIMINAL MISCHIEF 4TH, GRAFFIT
# 351484                           ASSAULT 2,1,UNCLASSIFIED
# 351485                     CRIMINAL MISCHIEF 4TH, GRAFFIT
# 351486                            LARCENY,PETIT FROM AUTO
# 351487       LARCENY,GRAND BY OPEN CREDIT CARD (NEW ACCT)
# 351488                              HARASSMENT,SUBD 3,4,5
# 351489                     LARCENY,PETIT FROM OPEN AREAS,
# 351490                          TRESPASS 4,CRIMINAL SUB 2
# 351491                   CRIMINAL MISCHIEF,UNCLASSIFIED 4
# 351492                     LARCENY,PETIT FROM OPEN AREAS,
# 351493                         HARASSMENT,SUBD 1,CIVILIAN
# 351494                           ASSAULT 2,1,UNCLASSIFIED
# 351495                     LARCENY,PETIT FROM BUILDING,UN
# 351496                          FRAUD,UNCLASSIFIED-FELONY
# 351497       LARCENY,GRAND BY IDENTITY THEFT-UNCLASSIFIED
# 351498                            AGGRAVATED HARASSMENT 2
# 351499                            AGGRAVATED HARASSMENT 2
# 351500                                       SEXUAL ABUSE
# 351501                              HARASSMENT,SUBD 3,4,5
# 351502                     LEAVING SCENE-ACCIDENT-PERSONA
# 351503                     LARCENY,PETIT BY FALSE PROMISE
# 351504                   CRIMINAL MISCHIEF,UNCLASSIFIED 4
# 351505                     LARCENY,PETIT FROM BUILDING,UN
# 351506                          FRAUD,UNCLASSIFIED-FELONY
# 351507                                          ASSAULT 3
# 351508                                             RAPE 3
#
#                     ...               ADDR_PCT_CD LOC_OF_OCCUR_DESC  \
# 0                   ...                      28.0           OUTSIDE
# 1                   ...                      76.0          FRONT OF
# 2                   ...                     121.0               NaN
# 3                   ...                      73.0            INSIDE
# 4                   ...                     110.0          FRONT OF
# 5                   ...                      43.0           REAR OF
# 6                   ...                     114.0            INSIDE
# 7                   ...                     103.0               NaN
# 8                   ...                     106.0          FRONT OF
# 9                   ...                      14.0            INSIDE
# 10                  ...                      72.0               NaN
# 11                  ...                     110.0            INSIDE
# 12                  ...                     110.0            INSIDE
# 13                  ...                     110.0            INSIDE
# 14                  ...                     110.0            INSIDE
# 15                  ...                     113.0               NaN
# 16                  ...                     121.0            INSIDE
# 17                  ...                       9.0       OPPOSITE OF
# 18                  ...                      34.0            INSIDE
# 19                  ...                      44.0          FRONT OF
# 20                  ...                      34.0            INSIDE
# 21                  ...                      49.0          FRONT OF
# 22                  ...                      67.0               NaN
# 23                  ...                     103.0          FRONT OF
# 24                  ...                     115.0            INSIDE
# 25                  ...                      50.0               NaN
# 26                  ...                      94.0          FRONT OF
# 27                  ...                      75.0            INSIDE
# 28                  ...                      34.0          FRONT OF
# 29                  ...                      44.0          FRONT OF
# ...                 ...                       ...               ...
# 351479              ...                      75.0               NaN
# 351480              ...                      61.0          FRONT OF
# 351481              ...                      63.0          FRONT OF
# 351482              ...                      52.0            INSIDE
# 351483              ...                     121.0           REAR OF
# 351484              ...                      63.0            INSIDE
# 351485              ...                     121.0           REAR OF
# 351486              ...                      52.0       OPPOSITE OF
# 351487              ...                     112.0            INSIDE
# 351488              ...                      19.0            INSIDE
# 351489              ...                       1.0               NaN
# 351490              ...                      70.0            INSIDE
# 351491              ...                      45.0            INSIDE
# 351492              ...                      47.0            INSIDE
# 351493              ...                      66.0            INSIDE
# 351494              ...                      73.0            INSIDE
# 351495              ...                       9.0            INSIDE
# 351496              ...                      62.0            INSIDE
# 351497              ...                      71.0            INSIDE
# 351498              ...                      90.0            INSIDE
# 351499              ...                      75.0            INSIDE
# 351500              ...                      44.0            INSIDE
# 351501              ...                      19.0            INSIDE
# 351502              ...                      46.0               NaN
# 351503              ...                      77.0               NaN
# 351504              ...                     106.0          FRONT OF
# 351505              ...                      94.0            INSIDE
# 351506              ...                      47.0            INSIDE
# 351507              ...                      62.0          FRONT OF
# 351508              ...                      24.0            INSIDE
#
#                      PREM_TYP_DESC PARKS_NM                 HADEVELOPT  \
# 0                              NaN      NaN                        NaN
# 1                           STREET      NaN                        NaN
# 2                           STREET      NaN                        NaN
# 3                      CHAIN STORE      NaN                        NaN
# 4                           STREET      NaN                        NaN
# 5       RESIDENCE - PUBLIC HOUSING      NaN                  SACK WERN
# 6           RESIDENCE - APT. HOUSE      NaN                        NaN
# 7                           STREET      NaN                        NaN
# 8                           STREET      NaN                        NaN
# 9                      CHAIN STORE      NaN                        NaN
# 10                          STREET      NaN                        NaN
# 11          RESIDENCE - APT. HOUSE      NaN                        NaN
# 12          RESIDENCE - APT. HOUSE      NaN                        NaN
# 13          RESIDENCE - APT. HOUSE      NaN                        NaN
# 14          RESIDENCE - APT. HOUSE      NaN                        NaN
# 15                AIRPORT TERMINAL      NaN                        NaN
# 16                 RESIDENCE-HOUSE      NaN                        NaN
# 17      RESIDENCE - PUBLIC HOUSING      NaN                       WALD
# 18                  BAR/NIGHT CLUB      NaN                        NaN
# 19                          STREET      NaN                        NaN
# 20                  BAR/NIGHT CLUB      NaN                        NaN
# 21                          STREET      NaN                        NaN
# 22               BUS (NYC TRANSIT)      NaN                        NaN
# 23                          STREET      NaN                        NaN
# 24                 RESIDENCE-HOUSE      NaN                        NaN
# 25                 PARK/PLAYGROUND      NaN                        NaN
# 26          RESIDENCE - APT. HOUSE      NaN                        NaN
# 27      RESIDENCE - PUBLIC HOUSING      NaN              CYPRESS HILLS
# 28                          STREET      NaN                        NaN
# 29          RESIDENCE - APT. HOUSE      NaN                        NaN
# ...                            ...      ...                        ...
# 351479            RESTAURANT/DINER      NaN                        NaN
# 351480             RESIDENCE-HOUSE      NaN                        NaN
# 351481                      STREET      NaN                        NaN
# 351482             RESIDENCE-HOUSE      NaN                        NaN
# 351483            RESTAURANT/DINER      NaN                        NaN
# 351484             RESIDENCE-HOUSE      NaN                        NaN
# 351485                 CHAIN STORE      NaN                        NaN
# 351486                      STREET      NaN                        NaN
# 351487             RESIDENCE-HOUSE      NaN                        NaN
# 351488      RESIDENCE - APT. HOUSE      NaN                        NaN
# 351489        TRANSIT - NYC SUBWAY      NaN                        NaN
# 351490             RESIDENCE-HOUSE      NaN                        NaN
# 351491      RESIDENCE - APT. HOUSE      NaN                        NaN
# 351492      RESIDENCE - APT. HOUSE      NaN                        NaN
# 351493                       OTHER      NaN                        NaN
# 351494             RESIDENCE-HOUSE      NaN                        NaN
# 351495                 CHAIN STORE      NaN                        NaN
# 351496      RESIDENCE - APT. HOUSE      NaN                        NaN
# 351497      OTHER HOUSE OF WORSHIP      NaN                        NaN
# 351498  RESIDENCE - PUBLIC HOUSING      NaN                   BUSHWICK
# 351499             RESIDENCE-HOUSE      NaN                        NaN
# 351500  RESIDENCE - PUBLIC HOUSING      NaN  CLAREMONT REHAB (GROUP 3)
# 351501      RESIDENCE - APT. HOUSE      NaN                        NaN
# 351502                      STREET      NaN                        NaN
# 351503                      STREET      NaN                        NaN
# 351504                      STREET      NaN                        NaN
# 351505              BAR/NIGHT CLUB      NaN                        NaN
# 351506             RESIDENCE-HOUSE      NaN                        NaN
# 351507              SMALL MERCHANT      NaN                        NaN
# 351508  RESIDENCE - PUBLIC HOUSING      NaN                   DOUGLASS
#
#        X_COORD_CD Y_COORD_CD   Latitude  Longitude  \
# 0        997960.0   231127.0  40.801064 -73.950482
# 1        982476.0   186071.0  40.677407 -74.006397
# 2        942825.0   166367.0  40.623227 -74.149227
# 3       1009882.0   177811.0  40.654698 -73.907624
# 4       1016026.0   211627.0  40.747495 -73.885321
# 5       1021993.0   238126.0  40.820204 -73.863637
# 6       1002768.0   220102.0  40.770794 -73.933146
# 7       1039125.0   192380.0  40.694554 -73.802113
# 8       1032780.0   186007.0  40.677098 -73.825040
# 9        988050.0   214940.0  40.756645 -73.986285
# 10       983262.0   179155.0  40.658424 -74.003562
# 11      1013783.0   211010.0  40.745809 -73.893419
# 12      1013783.0   211010.0  40.745809 -73.893419
# 13      1013783.0   211010.0  40.745809 -73.893419
# 14      1013783.0   211010.0  40.745809 -73.893419
# 15      1046315.0   187088.0  40.679981 -73.776234
# 16       943034.0   171263.0  40.636666 -74.148504
# 17       990468.0   202169.0  40.721590 -73.977569
# 18      1005509.0   253401.0  40.862185 -73.923145
# 19      1006823.0   243052.0  40.833776 -73.918429
# 20      1005509.0   253401.0  40.862185 -73.923145
# 21      1030939.0   253520.0  40.862413 -73.831208
# 22       998567.0   172445.0  40.639995 -73.948414
# 23      1051785.0   198161.0  40.710333 -73.756402
# 24      1019528.0   219616.0  40.769409 -73.872640
# 25      1017266.0   261201.0  40.883557 -73.880602
# 26       997245.0   204130.0  40.726965 -73.953117
# 27      1019193.0   183433.0  40.670097 -73.874038
# 28      1002792.0   249894.0  40.852565 -73.932977
# 29      1005700.0   245253.0  40.839820 -73.922480
# ...           ...        ...        ...        ...
# 351479  1014820.0   179358.0  40.658928 -73.889820
# 351480   997921.0   161182.0  40.609081 -73.950765
# 351481  1006769.0   167075.0  40.625238 -73.918879
# 351482  1018531.0   258225.0  40.875384 -73.876043
# 351483   938881.0   167697.0  40.626858 -74.163443
# 351484  1012234.0   163622.0  40.615745 -73.899206
# 351485   942825.0   166367.0  40.623227 -74.149227
# 351486  1019388.0   259017.0  40.877554 -73.872939
# 351487  1025551.0   198862.0  40.712419 -73.851024
# 351488   995728.0   216993.0  40.762273 -73.958568
# 351489   981005.0   197131.0  40.707763 -74.011706
# 351490   993121.0   170010.0  40.633319 -73.968041
# 351491  1031944.0   250456.0  40.853998 -73.827597
# 351492  1030439.0   263921.0  40.890963 -73.832944
# 351493   991675.0   161586.0  40.610198 -73.973260
# 351494  1011054.0   182428.0  40.667367 -73.903381
# 351495   986578.0   204044.0  40.726738 -73.991602
# 351496   990374.0   163503.0  40.615460 -73.977943
# 351497   996588.0   181055.0  40.663630 -73.955529
# 351498  1001438.0   194908.0  40.701646 -73.938012
# 351499  1015630.0   182164.0  40.666627 -73.886888
# 351500        NaN        NaN        NaN        NaN
# 351501   998840.0   224118.0  40.781825 -73.947319
# 351502  1011511.0   248284.0  40.848123 -73.901467
# 351503  1001868.0   183705.0  40.670895 -73.936491
# 351504  1038579.0   185782.0  40.676447 -73.804136
# 351505   995698.0   202372.0  40.722142 -73.958701
# 351506  1024111.0   263586.0  40.890075 -73.855834
# 351507   989361.0   162863.0  40.613704 -73.981593
# 351508        NaN        NaN        NaN        NaN
#
#                               Lat_Lon
# 0       (40.801063787, -73.950481913)
# 1       (40.677406703, -74.006397124)
# 2       (40.623226819, -74.149226973)
# 3       (40.654697919, -73.907623603)
# 4       (40.747494938, -73.885321074)
# 5       (40.820204108, -73.863637182)
# 6       (40.770794342, -73.933146158)
# 7        (40.694553524, -73.80211335)
# 8        (40.677098195, -73.82504028)
# 9       (40.756644557, -73.986285275)
# 10      (40.658423943, -74.003562398)
# 11      (40.745809203, -73.893418818)
# 12      (40.745809203, -73.893418818)
# 13      (40.745809203, -73.893418818)
# 14      (40.745809203, -73.893418818)
# 15      (40.679980738, -73.776233907)
# 16      (40.636666264, -74.148503993)
# 17      (40.721589955, -73.977569259)
# 18      (40.862184568, -73.923144894)
# 19      (40.833776359, -73.918429299)
# 20      (40.862184568, -73.923144894)
# 21      (40.862413323, -73.831208468)
# 22      (40.639994931, -73.948414287)
# 23       (40.710333401, -73.75640159)
# 24      (40.769409404, -73.872640367)
# 25      (40.883557017, -73.880602029)
# 26      (40.726965067, -73.953116629)
# 27      (40.670097208, -73.874037622)
# 28       (40.852565028, -73.93297722)
# 29      (40.839820265, -73.922480449)
# ...                               ...
# 351479  (40.658928422, -73.889820034)
# 351480   (40.609081374, -73.95076477)
# 351481  (40.625238367, -73.918878692)
# 351482  (40.875384004, -73.876042504)
# 351483  (40.626858064, -74.163443377)
# 351484   (40.615745029, -73.89920583)
# 351485  (40.623226819, -74.149226973)
# 351486  (40.877554428, -73.872939471)
# 351487  (40.712418824, -73.851023519)
# 351488  (40.762272884, -73.958567881)
# 351489  (40.707763436, -74.011705749)
# 351490  (40.633318501, -73.968040566)
# 351491   (40.853998204, -73.82759694)
# 351492  (40.890963439, -73.832944385)
# 351493   (40.610197706, -73.97325955)
# 351494    (40.66736709, -73.90338136)
# 351495  (40.726738256, -73.991602257)
# 351496  (40.615460472, -73.977943495)
# 351497  (40.663630486, -73.955529289)
# 351498  (40.701645727, -73.938012201)
# 351499  (40.666627433, -73.886887549)
# 351500                            NaN
# 351501  (40.781824561, -73.947318642)
# 351502  (40.848123442, -73.901466999)
# 351503  (40.670895214, -73.936490681)
# 351504  (40.676446932, -73.804135509)
# 351505  (40.722141921, -73.958701058)
# 351506  (40.890074824, -73.855833541)
# 351507  (40.613704446, -73.981592689)
# 351508                            NaN
#
# [351509 rows x 24 columns]

# %%
raw_crime_data = pd.read_csv('../new_data/NYPD_Complaint_Data_Current_YTD.csv')
raw_crime_data[['CMPLNT_FR_DT', 'CMPLNT_FR_TM','Latitude', 'Longitude', 'LAW_CAT_CD', 'CRM_ATPT_CPTD_CD']]\
                        .dropna()\
                        .groupby(['LAW_CAT_CD', 'CRM_ATPT_CPTD_CD']).size()
# Out:
# LAW_CAT_CD   CRM_ATPT_CPTD_CD
# FELONY       ATTEMPTED             3786
#              COMPLETED           100584
# MISDEMEANOR  ATTEMPTED             1786
#              COMPLETED           189151
# VIOLATION    ATTEMPTED              127
#              COMPLETED            50004
# dtype: int64

# %%
raw_crime_data.head(10).T
# Out:
#                                                  0  \
# CMPLNT_NUM                               160932883
# CMPLNT_FR_DT                            09/30/2017
# CMPLNT_FR_TM                              23:46:00
# CMPLNT_TO_DT                                   NaN
# CMPLNT_TO_TM                                   NaN
# RPT_DT                                  09/30/2017
# KY_CD                                          101
# OFNS_DESC          MURDER & NON-NEGL. MANSLAUGHTER
# PD_CD                                          NaN
# PD_DESC                                        NaN
# CRM_ATPT_CPTD_CD                         COMPLETED
# LAW_CAT_CD                                  FELONY
# JURIS_DESC                        N.Y. POLICE DEPT
# BORO_NM                                  MANHATTAN
# ADDR_PCT_CD                                     28
# LOC_OF_OCCUR_DESC                          OUTSIDE
# PREM_TYP_DESC                                  NaN
# PARKS_NM                                       NaN
# HADEVELOPT                                     NaN
# X_COORD_CD                                  997960
# Y_COORD_CD                                  231127
# Latitude                                   40.8011
# Longitude                                 -73.9505
# Lat_Lon              (40.801063787, -73.950481913)
#
#                                                1  \
# CMPLNT_NUM                             491504201
# CMPLNT_FR_DT                          09/30/2017
# CMPLNT_FR_TM                            23:20:00
# CMPLNT_TO_DT                          09/30/2017
# CMPLNT_TO_TM                            23:35:00
# RPT_DT                                09/30/2017
# KY_CD                                        344
# OFNS_DESC           ASSAULT 3 & RELATED OFFENSES
# PD_CD                                        101
# PD_DESC                                ASSAULT 3
# CRM_ATPT_CPTD_CD                       COMPLETED
# LAW_CAT_CD                           MISDEMEANOR
# JURIS_DESC                      N.Y. POLICE DEPT
# BORO_NM                                 BROOKLYN
# ADDR_PCT_CD                                   76
# LOC_OF_OCCUR_DESC                       FRONT OF
# PREM_TYP_DESC                             STREET
# PARKS_NM                                     NaN
# HADEVELOPT                                   NaN
# X_COORD_CD                                982476
# Y_COORD_CD                                186071
# Latitude                                 40.6774
# Longitude                               -74.0064
# Lat_Lon            (40.677406703, -74.006397124)
#
#                                                 2  \
# CMPLNT_NUM                              670710700
# CMPLNT_FR_DT                           09/30/2017
# CMPLNT_FR_TM                             23:20:00
# CMPLNT_TO_DT                           09/30/2017
# CMPLNT_TO_TM                             23:25:00
# RPT_DT                                 09/30/2017
# KY_CD                                         347
# OFNS_DESC          INTOXICATED & IMPAIRED DRIVING
# PD_CD                                         905
# PD_DESC               INTOXICATED DRIVING,ALCOHOL
# CRM_ATPT_CPTD_CD                        COMPLETED
# LAW_CAT_CD                            MISDEMEANOR
# JURIS_DESC                         PORT AUTHORITY
# BORO_NM                             STATEN ISLAND
# ADDR_PCT_CD                                   121
# LOC_OF_OCCUR_DESC                             NaN
# PREM_TYP_DESC                              STREET
# PARKS_NM                                      NaN
# HADEVELOPT                                    NaN
# X_COORD_CD                                 942825
# Y_COORD_CD                                 166367
# Latitude                                  40.6232
# Longitude                                -74.1492
# Lat_Lon             (40.623226819, -74.149226973)
#
#                                                3  \
# CMPLNT_NUM                             316507505
# CMPLNT_FR_DT                          09/30/2017
# CMPLNT_FR_TM                            23:20:00
# CMPLNT_TO_DT                                 NaN
# CMPLNT_TO_TM                                 NaN
# RPT_DT                                09/30/2017
# KY_CD                                        578
# OFNS_DESC                          HARRASSMENT 2
# PD_CD                                        638
# PD_DESC                    HARASSMENT,SUBD 3,4,5
# CRM_ATPT_CPTD_CD                       COMPLETED
# LAW_CAT_CD                             VIOLATION
# JURIS_DESC                      N.Y. POLICE DEPT
# BORO_NM                                 BROOKLYN
# ADDR_PCT_CD                                   73
# LOC_OF_OCCUR_DESC                         INSIDE
# PREM_TYP_DESC                        CHAIN STORE
# PARKS_NM                                     NaN
# HADEVELOPT                                   NaN
# X_COORD_CD                           1.00988e+06
# Y_COORD_CD                                177811
# Latitude                                 40.6547
# Longitude                               -73.9076
# Lat_Lon            (40.654697919, -73.907623603)
#
#                                                 4  \
# CMPLNT_NUM                              942412568
# CMPLNT_FR_DT                           09/30/2017
# CMPLNT_FR_TM                             23:15:00
# CMPLNT_TO_DT                           09/30/2017
# CMPLNT_TO_TM                             23:15:00
# RPT_DT                                 09/30/2017
# KY_CD                                         105
# OFNS_DESC                                 ROBBERY
# PD_CD                                         384
# PD_DESC            ROBBERY,POCKETBOOK/CARRIED BAG
# CRM_ATPT_CPTD_CD                        COMPLETED
# LAW_CAT_CD                                 FELONY
# JURIS_DESC                       N.Y. POLICE DEPT
# BORO_NM                                    QUEENS
# ADDR_PCT_CD                                   110
# LOC_OF_OCCUR_DESC                        FRONT OF
# PREM_TYP_DESC                              STREET
# PARKS_NM                                      NaN
# HADEVELOPT                                    NaN
# X_COORD_CD                            1.01603e+06
# Y_COORD_CD                                 211627
# Latitude                                  40.7475
# Longitude                                -73.8853
# Lat_Lon             (40.747494938, -73.885321074)
#
#                                                5  \
# CMPLNT_NUM                             207887383
# CMPLNT_FR_DT                          09/30/2017
# CMPLNT_FR_TM                            23:10:00
# CMPLNT_TO_DT                          09/30/2017
# CMPLNT_TO_TM                            23:12:00
# RPT_DT                                09/30/2017
# KY_CD                                        235
# OFNS_DESC                        DANGEROUS DRUGS
# PD_CD                                        567
# PD_DESC              MARIJUANA, POSSESSION 4 & 5
# CRM_ATPT_CPTD_CD                       COMPLETED
# LAW_CAT_CD                           MISDEMEANOR
# JURIS_DESC                   N.Y. HOUSING POLICE
# BORO_NM                                    BRONX
# ADDR_PCT_CD                                   43
# LOC_OF_OCCUR_DESC                        REAR OF
# PREM_TYP_DESC         RESIDENCE - PUBLIC HOUSING
# PARKS_NM                                     NaN
# HADEVELOPT                             SACK WERN
# X_COORD_CD                           1.02199e+06
# Y_COORD_CD                                238126
# Latitude                                 40.8202
# Longitude                               -73.8636
# Lat_Lon            (40.820204108, -73.863637182)
#
#                                                6  \
# CMPLNT_NUM                             914858070
# CMPLNT_FR_DT                          09/30/2017
# CMPLNT_FR_TM                            23:10:00
# CMPLNT_TO_DT                          09/30/2017
# CMPLNT_TO_TM                            23:18:00
# RPT_DT                                09/30/2017
# KY_CD                                        105
# OFNS_DESC                                ROBBERY
# PD_CD                                        390
# PD_DESC                    ROBBERY,HOME INVASION
# CRM_ATPT_CPTD_CD                       COMPLETED
# LAW_CAT_CD                                FELONY
# JURIS_DESC                      N.Y. POLICE DEPT
# BORO_NM                                   QUEENS
# ADDR_PCT_CD                                  114
# LOC_OF_OCCUR_DESC                         INSIDE
# PREM_TYP_DESC             RESIDENCE - APT. HOUSE
# PARKS_NM                                     NaN
# HADEVELOPT                                   NaN
# X_COORD_CD                           1.00277e+06
# Y_COORD_CD                                220102
# Latitude                                 40.7708
# Longitude                               -73.9331
# Lat_Lon            (40.770794342, -73.933146158)
#
#                                                 7  \
# CMPLNT_NUM                              646012974
# CMPLNT_FR_DT                           09/30/2017
# CMPLNT_FR_TM                             23:09:00
# CMPLNT_TO_DT                                  NaN
# CMPLNT_TO_TM                                  NaN
# RPT_DT                                 09/30/2017
# KY_CD                                         235
# OFNS_DESC                         DANGEROUS DRUGS
# PD_CD                                         511
# PD_DESC            CONTROLLED SUBSTANCE, POSSESSI
# CRM_ATPT_CPTD_CD                        COMPLETED
# LAW_CAT_CD                            MISDEMEANOR
# JURIS_DESC                       N.Y. POLICE DEPT
# BORO_NM                                    QUEENS
# ADDR_PCT_CD                                   103
# LOC_OF_OCCUR_DESC                             NaN
# PREM_TYP_DESC                              STREET
# PARKS_NM                                      NaN
# HADEVELOPT                                    NaN
# X_COORD_CD                            1.03912e+06
# Y_COORD_CD                                 192380
# Latitude                                  40.6946
# Longitude                                -73.8021
# Lat_Lon              (40.694553524, -73.80211335)
#
#                                               8  \
# CMPLNT_NUM                            690078111
# CMPLNT_FR_DT                         09/30/2017
# CMPLNT_FR_TM                           23:05:00
# CMPLNT_TO_DT                         09/30/2017
# CMPLNT_TO_TM                           23:22:00
# RPT_DT                               09/30/2017
# KY_CD                                       106
# OFNS_DESC                        FELONY ASSAULT
# PD_CD                                       109
# PD_DESC                ASSAULT 2,1,UNCLASSIFIED
# CRM_ATPT_CPTD_CD                      COMPLETED
# LAW_CAT_CD                               FELONY
# JURIS_DESC                     N.Y. POLICE DEPT
# BORO_NM                                  QUEENS
# ADDR_PCT_CD                                 106
# LOC_OF_OCCUR_DESC                      FRONT OF
# PREM_TYP_DESC                            STREET
# PARKS_NM                                    NaN
# HADEVELOPT                                  NaN
# X_COORD_CD                          1.03278e+06
# Y_COORD_CD                               186007
# Latitude                                40.6771
# Longitude                               -73.825
# Lat_Lon            (40.677098195, -73.82504028)
#
#                                                 9
# CMPLNT_NUM                              269331366
# CMPLNT_FR_DT                           09/30/2017
# CMPLNT_FR_TM                             23:02:00
# CMPLNT_TO_DT                           09/30/2017
# CMPLNT_TO_TM                             23:05:00
# RPT_DT                                 09/30/2017
# KY_CD                                         341
# OFNS_DESC                           PETIT LARCENY
# PD_CD                                         333
# PD_DESC            LARCENY,PETIT FROM STORE-SHOPL
# CRM_ATPT_CPTD_CD                        ATTEMPTED
# LAW_CAT_CD                            MISDEMEANOR
# JURIS_DESC                       N.Y. POLICE DEPT
# BORO_NM                                 MANHATTAN
# ADDR_PCT_CD                                    14
# LOC_OF_OCCUR_DESC                          INSIDE
# PREM_TYP_DESC                         CHAIN STORE
# PARKS_NM                                      NaN
# HADEVELOPT                                    NaN
# X_COORD_CD                                 988050
# Y_COORD_CD                                 214940
# Latitude                                  40.7566
# Longitude                                -73.9863
# Lat_Lon             (40.756644557, -73.986285275)

# %%
# Out:
# CMPLNT_FR_DT
# 01/01/1971      3
# 01/01/1973      1
# 01/01/1975      1
# 01/01/1978      1
# 01/01/1979      2
# 01/01/1981      2
# 01/01/1984      1
# 01/01/1986      1
# 01/01/1987      1
# 01/01/1990      1
# 01/01/1992      1
# 01/01/1993      1
# 01/01/1996      2
# 01/01/1998      2
# 01/01/1999      2
# 01/01/2001      4
# 01/01/2002      3
# 01/01/2003      3
# 01/01/2004      6
# 01/01/2005      3
# 01/01/2006     15
# 01/01/2007      5
# 01/01/2008      9
# 01/01/2009     10
# 01/01/2010     16
# 01/01/2011     18
# 01/01/2012     19
# 01/01/2013     24
# 01/01/2014     20
# 01/01/2015     43
#              ...
# 12/22/2015      4
# 12/22/2016    124
# 12/23/2014      1
# 12/23/2015      3
# 12/23/2016    148
# 12/24/2014      1
# 12/24/2016    102
# 12/25/2012      1
# 12/25/2015      1
# 12/25/2016     88
# 12/26/2012      2
# 12/26/2014      3
# 12/26/2015      1
# 12/26/2016    109
# 12/27/2015      1
# 12/27/2016    146
# 12/28/2012      1
# 12/28/2015      1
# 12/28/2016    191
# 12/29/2015      2
# 12/29/2016    179
# 12/30/2013      2
# 12/30/2014      2
# 12/30/2015      5
# 12/30/2016    244
# 12/31/2012      2
# 12/31/2013      3
# 12/31/2014      3
# 12/31/2015      3
# 12/31/2016    391
# Length: 1639, dtype: int64

# %%
timeSeries = raw_crime_data.groupby(['CMPLNT_FR_DT']).size()
plot_acf(timeSeries)
plt.show()
acf(timeSeries)
# Out:
# array([ 1.        , -0.19639618, -0.1655799 ,  0.00586295,  0.15394437,
#         0.07567221,  0.03378799, -0.00649659,  0.08024847,  0.0194696 ,
#         0.08047281,  0.00465602,  0.07181059, -0.01980267,  0.11083427,
#         0.03914215,  0.00761313,  0.03608497,  0.04614281,  0.04752709,
#         0.06551047,  0.01707124,  0.00541903,  0.05998683,  0.04154045,
#         0.00815091,  0.0677394 ,  0.04941866,  0.02903561,  0.00900866,
#         0.05555508,  0.07940152,  0.01457351, -0.00141309,  0.04241213,
#         0.09087688,  0.00572589, -0.00681413,  0.0412672 ,  0.04687626,
#         0.02688071])

# %%
plot_pacf(timeSeries)
plt.show()
pacf(timeSeries)
# Out:
# array([ 1.        , -0.19651608, -0.21261152, -0.08215651,  0.110982  ,
#         0.1422263 ,  0.15506834,  0.09624408,  0.1289541 ,  0.0566604 ,
#         0.107049  ,  0.04133734,  0.0882381 , -0.00691015,  0.09594221,
#         0.06246254,  0.02901366,  0.04496594,  0.0200547 ,  0.03536351,
#         0.05840555,  0.04247946, -0.00644979,  0.0338749 ,  0.00321921,
#        -0.01387233,  0.03718213,  0.04661086,  0.0373511 ,  0.00584269,
#         0.03430279,  0.06369292,  0.02742326, -0.00197517, -0.00194155,
#         0.04720052,  0.00192811, -0.02234943, -0.01552239, -0.0104547 ,
#        -0.01866257])

# %%
min_samples_split_values = np.logspace(1, 20, num=10, base=2).astype(np.int)
min_samples_leaf_values = np.logspace(1, 20, num=10, base=2).astype(np.int)

# %%
def getAccuracy(train, test, min_samples_split_value, min_samples_leaf_value):
    treeModel = DecisionTreeClassifier(criterion='entropy', min_samples_split = min_samples_split_value, min_samples_leaf = min_samples_leaf_value)
    
    treeModel.fit(train['X'], train['y'])
    testPredict = treeModel.predict(test['X'])
    
    return metrics.accuracy_score(testPredict, test['y'])
    
 
res = {}
for min_samples_split_value in min_samples_split_values:
    res[min_samples_split_value] = []

for min_samples_split_value in min_samples_split_values:
    for min_samples_leaf_value in min_samples_leaf_values:
        res[min_samples_split_value].append(getAccuracy({'X':X_train, 'y':y_train}, {'X':X_test, 'y':y_test}, min_samples_split_value, min_samples_leaf_value))
fig = plt.figure(figsize = (15, 6))
ax = fig.add_subplot(111)

for min_samples_split_value in min_samples_split_values:
    plt.plot(np.log2(min_samples_leaf_values), res[min_samples_split_value], 
             color=(np.random.rand(),np.random.rand(),np.random.rand()), label='Split={}'.format(np.floor(min_samples_split_value)))

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_xlabel('Min Leaf Size - Log2')
ax.set_ylabel('Test Set Accuracy')
plt.title('Accuracy by Hyperparameters')    
plt.show()

# %%
crime_count = new_dataset.groupby(['date', 'Y']).size()

# %%
crime_count
# Out:
# date
# 01/01/1990       1
# 01/01/1996       1
# 01/01/1998       1
# 01/01/2001       3
# 01/01/2002       2
# 01/01/2003       1
# 01/01/2004       3
# 01/01/2005       1
# 01/01/2006       3
# 01/01/2007       1
# 01/01/2009       3
# 01/01/2010       4
# 01/01/2011       3
# 01/01/2012       5
# 01/01/2013      16
# 01/01/2014      11
# 01/01/2015      23
# 01/01/2016      59
# 01/01/2017    1808
# 01/02/2013       1
# 01/02/2014       1
# 01/02/2015       1
# 01/02/2016       8
# 01/02/2017    1011
# 01/03/2005       1
# 01/03/2009       1
# 01/03/2012       1
# 01/03/2016      14
# 01/03/2017    1239
# 01/04/2012       1
#               ...
# 12/21/2015       1
# 12/21/2016     100
# 12/22/2015       4
# 12/22/2016     112
# 12/23/2014       1
# 12/23/2015       3
# 12/23/2016     144
# 12/24/2014       1
# 12/24/2016      95
# 12/25/2015       1
# 12/25/2016      83
# 12/26/2012       2
# 12/26/2014       3
# 12/26/2015       1
# 12/26/2016     102
# 12/27/2016     136
# 12/28/2012       1
# 12/28/2015       1
# 12/28/2016     177
# 12/29/2015       1
# 12/29/2016     172
# 12/30/2013       2
# 12/30/2014       2
# 12/30/2015       5
# 12/30/2016     235
# 12/31/2012       2
# 12/31/2013       1
# 12/31/2014       2
# 12/31/2015       3
# 12/31/2016     384
# Length: 1472, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd


a = pd.DatetimeIndex(start='2010-01-01',end='2014-01-01' , freq='D')
b = pd.Series(np.random.randn(len(a)), index=a)
fig, ax = plt.subplots()
ax.plot(b.index, b)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# %%
pd.to_datetime(crime_count['date'], errors='ignore', format='%m/%d/%Y')
# Out:
# 0       01/01/1990
# 1       01/01/1996
# 2       01/01/1998
# 3       01/01/2001
# 4       01/01/2002
# 5       01/01/2002
# 6       01/01/2003
# 7       01/01/2004
# 8       01/01/2004
# 9       01/01/2005
# 10      01/01/2006
# 11      01/01/2007
# 12      01/01/2009
# 13      01/01/2009
# 14      01/01/2010
# 15      01/01/2011
# 16      01/01/2012
# 17      01/01/2012
# 18      01/01/2013
# 19      01/01/2013
# 20      01/01/2014
# 21      01/01/2014
# 22      01/01/2014
# 23      01/01/2015
# 24      01/01/2015
# 25      01/01/2015
# 26      01/01/2016
# 27      01/01/2016
# 28      01/01/2016
# 29      01/01/2017
#            ...
# 2712    12/26/2016
# 2713    12/27/2016
# 2714    12/27/2016
# 2715    12/27/2016
# 2716    12/28/2012
# 2717    12/28/2015
# 2718    12/28/2016
# 2719    12/28/2016
# 2720    12/28/2016
# 2721    12/29/2015
# 2722    12/29/2016
# 2723    12/29/2016
# 2724    12/29/2016
# 2725    12/30/2013
# 2726    12/30/2013
# 2727    12/30/2014
# 2728    12/30/2015
# 2729    12/30/2015
# 2730    12/30/2016
# 2731    12/30/2016
# 2732    12/30/2016
# 2733    12/31/2012
# 2734    12/31/2013
# 2735    12/31/2014
# 2736    12/31/2014
# 2737    12/31/2015
# 2738    12/31/2015
# 2739    12/31/2016
# 2740    12/31/2016
# 2741    12/31/2016
# Name: date, Length: 2742, dtype: object

# %%
crime_count.loc[crime_count['Y'] == 1].drop('Y', axis='columns').rename(index=int, columns={0:'crime_count'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2482             try:
# -> 2483                 return libts.get_value_box(s, key)
#    2484             except IndexError:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.get_value_box (pandas/_libs/tslib.c:18843)()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.get_value_box (pandas/_libs/tslib.c:18477)()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-f2fe4e172db8> in <module>()
# ----> 1 crime_count.loc[crime_count['Y'] == 1].drop('Y', axis='columns').rename(index=int, columns={0:'crime_count'})
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2489                     raise InvalidIndexError(key)
#    2490                 else:
# -> 2491                     raise e1
#    2492             except Exception:  # pragma: no cover
#    2493                 raise e1
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2475         try:
#    2476             return self._engine.get_value(s, k,
# -> 2477                                           tz=getattr(series.dtype, 'tz', None))
#    2478         except KeyError as e1:
#    2479             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Y'
